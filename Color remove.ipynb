# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
print("hello world !")
# Out:
# hello world !

# %%
img = Image.open("bird.jpeg")

img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=196x350>

# %%
imgArr = np.array(img)

# %%
img.size
# Out:
# (196, 350)

# %%
firstquad = imgArr[0:175,0:93,:]
firstquad[:,:,0] = np.clip(firstquad[:,:,0]+0,255,45)
plt.imshow(firstquad)
# plt.axis("off")
plt.show()

# %%
firstquad = imgArr[0:175,93:,:]
firstquad[:,:,1] = np.clip(firstquad[:,:,1]+0,255,45)
plt.imshow(firstquad)
# plt.axis("off")
plt.show()

# %%
firstquad = imgArr[175:,0:93,:]
firstquad[:,:,2] = np.clip(firstquad[:,:,2]+0,255,45)
plt.imshow(firstquad)
# plt.axis("off")
plt.show()

# %%
firstquad = imgArr[175:,93:,:]
firstquad[:,:,1] = np.clip(firstquad[:,:,1]+0,255,45)
plt.imshow(firstquad)
# plt.axis("off")
plt.show()

# %%
firstquad = imgArr[175:,93:,:]
firstquad[:,:,0] = np.clip(firstquad[:,:,0]+0,255,45)
plt.imshow(firstquad)
# plt.axis("off")
plt.show()

# %%
plt.imshow(imgArr)
# plt.axis("off")
plt.show()
