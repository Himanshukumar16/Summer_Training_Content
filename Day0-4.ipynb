# %%
a = 10
print(a)
# Out:
# 10

# %%
for i in range(5) :
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
5 > 3 && 3 < 9
# Out:
#   Cell In[3], line 1
#     5 > 3 && 3 < 9
#            ^
# SyntaxError: invalid syntax

# %%
5 > 3 & 3 > 1
# Out:
# True

# %%
5 > 3 and 3 > 1
# Out:
# True

# %%
5 > 3 AND 3 > 1
# Out:
#   Cell In[6], line 1
#     5 > 3 AND 3 > 1
#           ^
# SyntaxError: invalid syntax

# %%
for i in range(5) :
    for j in range (i) :
        print(i)
# Out:
# 1
# 2
# 2
# 3
# 3
# 3
# 4
# 4
# 4
# 4

# %%
for i in range(5) :
    for j in range (i+1) :
        print("*",end = " ")
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
for i in range(5) :
    for j in range(5- i - 1) :
        print(" ",end = "")
    for k in range(i) :
        print("*", end="")
    for l in range (i+1) :
        print("*",end = "")
    print()
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
print("this is a sample code !")
# Out:
# this is a sample code !

# %%
n = int(input("Enter the number of lines in the pattern"))
for i in range(n) :
    for j in range(n- i - 1) :
        print(" ",end = "")
    for k in range(i) :
        print("*", end="")
    for l in range (i+1) :
        print("*",end = "")
    print()
# Out:
# Enter the number of lines in the pattern 10
#          *
#         ***
#        *****
#       *******
#      *********
#     ***********
#    *************
#   ***************
#  *****************
# *******************

# %%
print("Hellllllloooooo...")
# Out:
# Hellllllloooooo...

# %%
print("This is a new Layout !")
# Out:
# This is a new Layout !
