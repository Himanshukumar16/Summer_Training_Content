# %%
# Day- 06 :

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
print("Hello World !!")
# Out:
# Hello World !!

# %%
img = Image.open("photo.jpg")

imgArr = np.array(img)

imgArr[:,:,0] = np.clip(imgArr[:,:,0]+0,0,0)

plt.imshow(imgArr)
plt.axis("off")
plt.show()

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Names" : ["ABC","DEF","GHI","JKL","MNO"],
    "marks" : [90,95,65,30,100]
})
df
# Out:
#   Names  marks
# 0   ABC     90
# 1   DEF     95
# 2   GHI     65
# 3   JKL     30
# 4   MNO    100

# %%
df.head()
# Out:
#   Names  marks
# 0   ABC     90
# 1   DEF     95
# 2   GHI     65
# 3   JKL     30
# 4   MNO    100

# %%
df.sample()
# Out:
#   Names  marks
# 2   GHI     65

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool
